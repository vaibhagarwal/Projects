# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
plt.rcParams['figure.figsize'] = (15, 12)

# %%
df_1 = pd.DataFrame(json.load(open('logins.json')))

# %%
df_1.head()
# Out:
#             login_time
# 0  1970-01-01 20:13:18
# 1  1970-01-01 20:16:10
# 2  1970-01-01 20:16:37
# 3  1970-01-01 20:16:36
# 4  1970-01-01 20:26:21

# %%
df_1.tail()
# Out:
#                 login_time
# 93137  1970-04-13 18:50:19
# 93138  1970-04-13 18:43:56
# 93139  1970-04-13 18:54:02
# 93140  1970-04-13 18:57:38
# 93141  1970-04-13 18:54:23

# %%
df_1['count'] = 1

# %%
df_1.login_time = pd.to_datetime(df_1.login_time)

# %%
df_1.set_index('login_time', inplace=True)

# %%
df_2 = df_1.resample('15T').count()

# %%
min(df_1.index)
# Out:
# Timestamp('1970-01-01 20:12:16')

# %%
max(df_1.index)
# Out:
# Timestamp('1970-04-13 18:57:38')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9788 entries, 1970-01-01 20:00:00 to 1970-04-13 18:45:00
# Freq: 15T
# Data columns (total 1 columns):
# count    9788 non-null int64
# dtypes: int64(1)
# memory usage: 152.9 KB

# %%
plt.figure(figsize=[15,15])
plt.plot(df_2)
# Out:
# C:\Users\agarw\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(df_2[(df_2.index > '1970-01-01') & (df_2.index <= '1970-01-31')])

# %%
plt.plot(df_2[(df_2.index > '1970-02-01') & (df_2.index <= '1970-02-28')])

# %%
plt.plot(df_2[(df_2.index > '1970-03-01') & (df_2.index <= '1970-03-31')])

# %%
plt.plot(df_2[(df_2.index > '1970-04-01') & (df_2.index <= '1970-04-15')])

# %%
plt.plot(df_2[(df_2.index > '1970-01-01') & (df_2.index < '1970-01-08')])

# %%
plt.plot(df_2[(df_2.index > '1970-01-08') & (df_2.index < '1970-01-15')])

# %%
plt.plot(df_2[(df_2.index > '1970-01-02') & (df_2.index <= '1970-01-04')])

# %%
df_2.head(20)
# Out:
#                      count
# login_time
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1
# 1970-01-01 21:15:00      4
# 1970-01-01 21:30:00      0
# 1970-01-01 21:45:00      4
# 1970-01-01 22:00:00      9
# 1970-01-01 22:15:00      8
# 1970-01-01 22:30:00      1
# 1970-01-01 22:45:00      3
# 1970-01-01 23:00:00     16
# 1970-01-01 23:15:00     13
# 1970-01-01 23:30:00     14
# 1970-01-01 23:45:00     15
# 1970-01-02 00:00:00     10
# 1970-01-02 00:15:00     18
# 1970-01-02 00:30:00     12
# 1970-01-02 00:45:00     13
