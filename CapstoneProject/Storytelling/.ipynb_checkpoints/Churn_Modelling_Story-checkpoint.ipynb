# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_1 = pd.read_csv('Churn_Modelling_Wrangled.csv')

# %%
df = pd.DataFrame(file_1)

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave        619.0    France  Female  42.0     2.0
# 1    15647311      Hill        608.0     Spain  Female  41.0     1.0
# 2    15619304      Onio        502.0    France  Female  42.0     8.0
# 3    15701354      Boni        699.0    France  Female  39.0     1.0
# 4    15737888  Mitchell        850.0     Spain  Female  43.0     2.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00            1.0        1.0             1.0        101348.88
# 1   83807.86            1.0        0.0             1.0        112542.58
# 2  159660.80            3.0        1.0             0.0        113931.57
# 3       0.00            2.0        0.0             0.0         93826.63
# 4  125510.82            1.0        1.0             1.0         79084.10
#
#    Exited
# 0     1.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0

# %%
df.set_index('CustomerId', inplace=True)
df.head()
# Out:
#              Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15634602    Hargrave        619.0    France  Female  42.0     2.0       0.00
# 15647311        Hill        608.0     Spain  Female  41.0     1.0   83807.86
# 15619304        Onio        502.0    France  Female  42.0     8.0  159660.80
# 15701354        Boni        699.0    France  Female  39.0     1.0       0.00
# 15737888    Mitchell        850.0     Spain  Female  43.0     2.0  125510.82
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15634602              1.0        1.0             1.0        101348.88     1.0
# 15647311              1.0        0.0             1.0        112542.58     0.0
# 15619304              3.0        1.0             0.0        113931.57     1.0
# 15701354              2.0        0.0             0.0         93826.63     0.0
# 15737888              1.0        1.0             1.0         79084.10     0.0

# %%
plt.scatter(df.Age, df.EstimatedSalary)

# %%
df[df.Age > 80].shape
# Out:
# (12, 12)

# %%
df.loc[df.Exited == 0, :].groupby(['Geography', 'Gender']).mean()
# Out:
#                   CreditScore        Age    Tenure        Balance  \
# Geography Gender
# France    Female   650.437222  37.088889  4.958333   58447.791411
#           Male     651.677903  37.343321  5.038702   61723.161910
# Germany   Female   654.373494  37.344043  4.890228  118876.363788
#           Male     652.108307  37.279706  5.097792  119928.066183
# Spain     Female   653.714452  38.008159  5.089744   56438.797133
#           Male     651.248963  37.721992  5.124481   61802.424124
#
#                   NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography Gender
# France    Female       1.556667   0.697778        0.550000     98529.447111
#           Male         1.530587   0.714107        0.542655     99752.604136
# Germany   Female       1.536814   0.708166        0.528782    103987.854029
#           Male         1.560463   0.723449        0.588854    101195.126604
# Spain     Female       1.567599   0.715618        0.566434     98912.450082
#           Male         1.529461   0.687967        0.568465     98377.151627
#
#                   Exited
# Geography Gender
# France    Female     0.0
#           Male       0.0
# Germany   Female     0.0
#           Male       0.0
# Spain     Female     0.0
#           Male       0.0

# %%
df.loc[df.Exited == 1, :].groupby(['Geography', 'Gender']).mean()
# Out:
#                   CreditScore        Age    Tenure        Balance  \
# Geography Gender
# France    Female   643.897826  45.332609  4.921739   67755.162630
#           Male     639.320917  44.868195  5.114613   75927.764269
# Germany   Female   650.732143  44.828125  5.075893  119520.811897
#           Male     643.964481  44.975410  4.920765  121202.242432
# Spain     Female   645.363636  43.610390  4.679654   71997.673680
#           Male     650.175824  44.769231  4.626374   73167.867802
#
#                   NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography Gender
# France    Female       1.510870   0.697826        0.373913    103626.025065
#           Male         1.426934   0.710602        0.361032    102979.302464
# Germany   Female       1.466518   0.709821        0.368304     99884.458728
#           Male         1.434426   0.710383        0.357923     96591.601257
# Spain     Female       1.597403   0.679654        0.333333    107544.095758
#           Male         1.406593   0.664835        0.351648     98661.099011
#
#                   Exited
# Geography Gender
# France    Female     1.0
#           Male       1.0
# Germany   Female     1.0
#           Male       1.0
# Spain     Female     1.0
#           Male       1.0

# %%
df_1 = df.loc[df.Exited == 0, :]

# %%
df_2 = df.loc[df.Exited == 1, :]

# %%
sns.jointplot(x='Age', y='EstimatedSalary', data=df_1, kind='hex')

# %%
sns.jointplot(x='Age', y='EstimatedSalary', data=df_2, kind='hex', color = 'green')

# %%
sns.jointplot(x='Age', y='CreditScore', data=df_2, kind='hex', color='Red')
