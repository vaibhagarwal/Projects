# %% [markdown]
# Questions:
# 1) What age group is the most leaving the bank?
# 2) Is there a correaltion of customers who exited the bank with Estimated salary?
# 3) Was it male or female for a particular age group who churned the most?
# 4) Most customers left of which country?
# 5) How many active members left the bank? Any relation between them?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_1 = pd.read_csv('Churn_Modelling_Wrangled.csv')

# %%
df = pd.DataFrame(file_1)

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave        619.0    France  Female  42.0     2.0
# 1    15647311      Hill        608.0     Spain  Female  41.0     1.0
# 2    15619304      Onio        502.0    France  Female  42.0     8.0
# 3    15701354      Boni        699.0    France  Female  39.0     1.0
# 4    15737888  Mitchell        850.0     Spain  Female  43.0     2.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00            1.0        1.0             1.0        101348.88
# 1   83807.86            1.0        0.0             1.0        112542.58
# 2  159660.80            3.0        1.0             0.0        113931.57
# 3       0.00            2.0        0.0             0.0         93826.63
# 4  125510.82            1.0        1.0             1.0         79084.10
#
#    Exited
# 0     1.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0

# %%
df.set_index('CustomerId', inplace=True)
df.head()
# Out:
#              Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15634602    Hargrave        619.0    France  Female  42.0     2.0       0.00
# 15647311        Hill        608.0     Spain  Female  41.0     1.0   83807.86
# 15619304        Onio        502.0    France  Female  42.0     8.0  159660.80
# 15701354        Boni        699.0    France  Female  39.0     1.0       0.00
# 15737888    Mitchell        850.0     Spain  Female  43.0     2.0  125510.82
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15634602              1.0        1.0             1.0        101348.88     1.0
# 15647311              1.0        0.0             1.0        112542.58     0.0
# 15619304              3.0        1.0             0.0        113931.57     1.0
# 15701354              2.0        0.0             0.0         93826.63     0.0
# 15737888              1.0        1.0             1.0         79084.10     0.0

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.532900     38.918900      5.012300   76479.494987       1.530000
# std       96.636801     10.486759      2.891433   62393.555997       0.581493
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97173.290000       1.000000
# 75%      717.250000     44.000000      7.000000  127639.372500       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70570        0.515500    100089.287258      0.203600
# std        0.45575        0.499785     57498.826249      0.402695
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(df_1.Age, df_1.EstimatedSalary)

# %%
plt.figure(figsize=(12,8))
plt.scatter(df_2.Age, df_2.EstimatedSalary)

# %%
df[df.Age > 80].shape
# Out:
# (12, 12)

# %%
df.loc[df.Exited == 0, :].groupby(['Geography', 'Gender']).median()
# Out:
#                   CreditScore   Age  Tenure    Balance  NumOfProducts  \
# Geography Gender
# France    Female        654.0  35.0     5.0       0.00            2.0
#           Male          655.0  36.0     5.0   61811.23            2.0
# Germany   Female        652.0  36.0     5.0  120074.97            2.0
#           Male          653.0  36.0     5.0  120596.93            2.0
# Spain     Female        654.0  36.0     5.0       0.00            2.0
#           Male          650.0  36.0     5.0   65521.20            2.0
#
#                   HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Geography Gender
# France    Female        1.0             1.0         98243.92     0.0
#           Male          1.0             1.0         98060.51     0.0
# Germany   Female        1.0             1.0        105221.76     0.0
#           Male          1.0             1.0        102184.66     0.0
# Spain     Female        1.0             1.0        101401.59     0.0
# ...

# %%
df.loc[df.Exited == 1, :].groupby(['Geography', 'Gender']).median()
# Out:
#                   CreditScore   Age  Tenure     Balance  NumOfProducts  \
# Geography Gender
# France    Female        644.0  45.0     5.0   71423.565            1.0
#           Male          643.0  45.0     5.0   89079.410            1.0
# Germany   Female        650.0  45.0     5.0  118160.745            1.0
#           Male          638.0  45.0     5.0  119972.775            1.0
# Spain     Female        650.0  44.0     5.0   75990.970            1.0
#           Male          648.0  44.0     4.0   80048.440            1.0
#
#                   HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Geography Gender
# France    Female        1.0             0.0       101194.205     1.0
#           Male          1.0             0.0       103799.770     1.0
# Germany   Female        1.0             0.0       103177.515     1.0
#           Male          1.0             0.0        92401.215     1.0
# Spain     Female        1.0             0.0       112649.220     1.0
# ...

# %%
df_1 = df.loc[df.Exited == 0, :]

# %%
df_2 = df.loc[df.Exited == 1, :]

# %%
df.loc[(df.Exited == 1) & (df.IsActiveMember == 1)].shape
# Out:
# (735, 12)

# %%
sns.jointplot(x='Age', y='EstimatedSalary', data=df_1, kind='hex')

# %%
sns.jointplot(x='Age', y='EstimatedSalary', data=df_2, kind='hex', color = 'green')

# %%
sns.jointplot(x='Age', y='CreditScore', data=df_2, kind='hex', color='Red')

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.distplot(df_1['Age'])
plt.title('Still with Bank')
plt.subplot(1,2,2)
sns.distplot(df_2['Age'])
plt.title('Left the Bank')
# Out:
# Text(0.5, 1.0, 'Left the Bank')

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.distplot(df_1['EstimatedSalary'], kde=False, bins=100, color='purple')
plt.subplot(1,2,2)
sns.distplot(df_2['EstimatedSalary'], kde=False, bins=100, color='purple')

# %%
#df_2.Age.value_counts()

# %%
#s_1 = df_2.Age.apply(lambda x: x-df_1.Age)

# %%
df.groupby('Geography').mean()
# Out:
#            CreditScore        Age    Tenure        Balance  NumOfProducts  \
# Geography
# France      649.657821  38.509178  5.004389   62089.574451       1.530926
# Germany     651.349920  39.766322  5.006369  119728.335649       1.518312
# Spain       651.475363  38.888530  5.034330   61730.381086       1.539984
#
#            HasCrCard  IsActiveMember  EstimatedSalary    Exited
# Geography
# France      0.706504        0.517159     99893.507708  0.161413
# Germany     0.714570        0.498010    101121.120991  0.324045
# Spain       0.695073        0.529887     99438.754451  0.166801

# %%
df_1.groupby('Geography').count()
# Out:
#            Surname  CreditScore  Gender   Age  Tenure  Balance  NumOfProducts  \
# Geography
# France        4203         4203    4203  4203    4203     4203           4203
# Germany       1698         1698    1698  1698    1698     1698           1698
# Spain         2063         2063    2063  2063    2063     2063           2063
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Geography
# France          4203            4203             4203    4203
# Germany         1698            1698             1698    1698
# Spain           2063            2063             2063    2063

# %%
df_2.groupby('Geography').count()
# Out:
#            Surname  CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  \
# Geography
# France         809          809     809  809     809      809            809
# Germany        814          814     814  814     814      814            814
# Spain          413          413     413  413     413      413            413
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Geography
# France           809             809              809     809
# Germany          814             814              814     814
# Spain            413             413              413     413

# %%
df_3 = df.loc[(df.IsActiveMember==1)&(df.Exited==1),:]

# %%
df_3.shape
# Out:
# (735, 12)

# %%
df_3.describe()
# Out:
#        CreditScore         Age      Tenure        Balance  NumOfProducts  \
# count   735.000000  735.000000  735.000000     735.000000     735.000000
# mean    645.247619   44.763265    4.789116   91320.636476       1.531973
# std      97.869686    9.879437    2.936270   58574.133553       0.845729
# min     350.000000   18.000000    0.000000       0.000000       1.000000
# 25%     581.000000   38.000000    2.000000   44441.750000       1.000000
# 50%     644.000000   45.000000    5.000000  109922.610000       1.000000
# 75%     715.500000   51.000000    7.000000  131393.860000       2.000000
# max     850.000000   74.000000   10.000000  250898.090000       4.000000
#
#         HasCrCard  IsActiveMember  EstimatedSalary  Exited
# count  735.000000           735.0       735.000000   735.0
# mean     0.655782             1.0    100654.022367     1.0
# std      0.475436             0.0     57903.233747     0.0
# min      0.000000             1.0        11.580000     1.0
# ...

# %%
df.groupby(['Geography','Gender']).mean()
# Out:
#                   CreditScore        Age    Tenure        Balance  \
# Geography Gender
# France    Female   649.106195  38.766814  4.950885   60342.212102
#           Male     650.110828  38.297602  5.048328   63524.544985
# Germany   Female   653.008368  40.149791  4.959833  119117.964418
#           Male     649.845103  39.418375  5.048595  120282.165277
# Spain     Female   651.943067  39.196511  5.002755   59739.164885
#           Male     651.108147  38.646720  5.059120   63293.780108
#
#                   NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography Gender
# France    Female       1.547345   0.697788        0.514159     99566.803686
#           Male         1.517442   0.713663        0.519622    100161.803888
# Germany   Female       1.510460   0.708787        0.468619    102449.510017
#           Male         1.525437   0.719818        0.524677     99915.786986
# Spain     Female       1.573921   0.707989        0.516988    100743.405225
# ...
