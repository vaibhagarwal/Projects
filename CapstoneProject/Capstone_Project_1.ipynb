# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file_1= pd.read_csv('Churn_Modelling_AccDetails.csv')

# %%
file_2= pd.read_csv('Churn_Modelling_CustDetails.csv')

# %%
data_1=pd.DataFrame(file_1)

# %%
data_1.head()
# Out:
#    CustomerId  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0    15634602     2.0       0.00            1.0        1.0             1.0
# 1    15647311     1.0   83807.86            1.0        0.0             1.0
# 2    15619304     8.0  159660.80            3.0        1.0             0.0
# 3    15701354     1.0       0.00            2.0        0.0             0.0
# 4    15737888     2.0  125510.82            1.0        1.0             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88     1.0
# 1        112542.58     0.0
# 2        113931.57     1.0
# 3         93826.63     0.0
# 4         79084.10     0.0

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
# CustomerId         10000 non-null int64
# Tenure             9995 non-null float64
# Balance            9997 non-null float64
# NumOfProducts      9995 non-null float64
# HasCrCard          9993 non-null float64
# IsActiveMember     9996 non-null float64
# EstimatedSalary    9997 non-null float64
# Exited             9996 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 625.1 KB

# %%
data_1.CustomerId.nunique()
# Out:
# 10000

# %%
data_2=pd.DataFrame(file_2)

# %%
data_2.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age
# 0    15634602  Hargrave        619.0    France  Female  42.0
# 1    15647311      Hill        608.0     Spain  Female  41.0
# 2    15619304      Onio        502.0    France  Female  42.0
# 3    15701354      Boni        699.0    France  Female  39.0
# 4    15737888  Mitchell        850.0     Spain  Female  43.0

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
# CustomerId     10000 non-null int64
# Surname        9996 non-null object
# CreditScore    9997 non-null float64
# Geography      9994 non-null object
# Gender         9997 non-null object
# Age            9992 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 468.8+ KB

# %%
data_2.CustomerId.nunique()
# Out:
# 10000

# %%
df = pd.merge(data_2, data_1, on='CustomerId', how='outer')
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave        619.0    France  Female  42.0     2.0
# 1    15647311      Hill        608.0     Spain  Female  41.0     1.0
# 2    15619304      Onio        502.0    France  Female  42.0     8.0
# 3    15701354      Boni        699.0    France  Female  39.0     1.0
# 4    15737888  Mitchell        850.0     Spain  Female  43.0     2.0
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00            1.0        1.0             1.0        101348.88
# 1   83807.86            1.0        0.0             1.0        112542.58
# 2  159660.80            3.0        1.0             0.0        113931.57
# 3       0.00            2.0        0.0             0.0         93826.63
# 4  125510.82            1.0        1.0             1.0         79084.10
#
#    Exited
# 0     1.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0

# %%
df.set_index('CustomerId', inplace=True)
df.head()
# Out:
#              Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15634602    Hargrave        619.0    France  Female  42.0     2.0       0.00
# 15647311        Hill        608.0     Spain  Female  41.0     1.0   83807.86
# 15619304        Onio        502.0    France  Female  42.0     8.0  159660.80
# 15701354        Boni        699.0    France  Female  39.0     1.0       0.00
# 15737888    Mitchell        850.0     Spain  Female  43.0     2.0  125510.82
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15634602              1.0        1.0             1.0        101348.88     1.0
# 15647311              1.0        0.0             1.0        112542.58     0.0
# 15619304              3.0        1.0             0.0        113931.57     1.0
# 15701354              2.0        0.0             0.0         93826.63     0.0
# 15737888              1.0        1.0             1.0         79084.10     0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
# Surname            9996 non-null object
# CreditScore        9997 non-null float64
# Geography          9994 non-null object
# Gender             9997 non-null object
# Age                9992 non-null float64
# Tenure             9995 non-null float64
# Balance            9997 non-null float64
# NumOfProducts      9995 non-null float64
# HasCrCard          9993 non-null float64
# IsActiveMember     9996 non-null float64
# EstimatedSalary    9997 non-null float64
# Exited             9996 non-null float64
# dtypes: float64(9), object(3)
# memory usage: 1015.6+ KB

# %%
df.describe()
# Out:
#        CreditScore          Age       Tenure        Balance  NumOfProducts  \
# count  9997.000000  9992.000000  9995.000000    9997.000000    9995.000000
# mean    650.533060    38.920036     5.012306   76482.439719       1.530165
# std      96.651301    10.490870     2.892156   62396.701122       0.581523
# min     350.000000    18.000000     0.000000       0.000000       1.000000
# 25%     584.000000    32.000000     3.000000       0.000000       1.000000
# 50%     652.000000    37.000000     5.000000   97188.620000       1.000000
# 75%     718.000000    44.000000     7.000000  127642.440000       2.000000
# max     850.000000    92.000000    10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary       Exited
# count  9993.000000     9996.000000      9997.000000  9996.000000
# mean      0.705494        0.515306    100089.614142     0.203681
# std       0.455843        0.499791     57507.450780     0.402755
# ...

# %%
df[pd.isnull(df['Surname'])]
# Out:
#            Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15790678       NaN        475.0    France  Female  32.0     8.0  119023.28
# 15672610       NaN        567.0     Spain    Male  40.0     4.0  118628.80
# 15607263       NaN        788.0    France    Male  55.0     3.0       0.00
# 15778515       NaN        748.0    France    Male  40.0     3.0   95297.11
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15790678              1.0        1.0             0.0        100816.29     0.0
# 15672610              1.0        0.0             0.0         91973.63     0.0
# 15607263              1.0        0.0             1.0         13288.46     1.0
# 15778515              1.0        0.0             0.0        171515.84     0.0

# %%
df.Surname.fillna('noname' , inplace=True)

# %%
df[pd.isnull(df['CreditScore'])]
# Out:
#               Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15691840       Fraser          NaN   Germany  Female  37.0     6.0  159863.90
# 15770214       Bryant          NaN    France  Female  27.0     7.0       0.00
# 15809872    Ikechukwu          NaN    France    Male  32.0     2.0   84906.45
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15691840              2.0        0.0             1.0        125307.87     0.0
# 15770214              2.0        1.0             0.0        144134.64     0.0
# 15809872              1.0        1.0             0.0        163216.48     0.0

# %%
a = df.CreditScore.mean()
a
# Out:
# 650.5330599179754

# %%
df.CreditScore.fillna(int(a) , inplace=True)

# %%
df[pd.isnull(df['Geography'])]
# Out:
#             Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15788448     Watson        490.0       NaN    Male  31.0     3.0  145260.23
# 15592461    Jackson        603.0       NaN    Male  26.0     4.0  109166.37
# 15755209         Fu        484.0       NaN  Female  35.0     7.0  133868.21
# 15686696      Brown        817.0       NaN  Female  37.0     6.0   81070.34
# 15708139      Brown        575.0       NaN  Female  40.0     1.0  139532.34
# 15605339      Baker        673.0       NaN  Female  37.0    10.0       0.00
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15788448              1.0        0.0             1.0        114066.77     0.0
# 15592461              1.0        1.0             1.0         92840.67     0.0
# 15755209              1.0        1.0             1.0         27286.10     0.0
# 15686696              2.0        1.0             0.0         80985.88     0.0
# ...

# %%
df.Geography.value_counts()
# Out:
# France     5011
# Germany    2508
# Spain      2475
# Name: Geography, dtype: int64

# %%
df.groupby(['Geography','Gender']).median()
# Out:
#                   CreditScore   Age  Tenure     Balance  NumOfProducts  \
# Geography Gender
# France    Female        652.0  37.0     5.0   47450.425            2.0
#           Male          653.5  37.0     5.0   69278.675            1.0
# Germany   Female        651.0  39.0     5.0  118902.350            1.0
#           Male          651.0  38.0     5.0  120193.785            1.0
# Spain     Female        653.0  38.0     5.0       0.000            2.0
#           Male          650.0  37.0     5.0   69543.355            1.0
#
#                   HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Geography Gender
# France    Female        1.0             1.0        99520.855     0.0
#           Male          1.0             1.0        98931.500     0.0
# Germany   Female        1.0             0.0       104617.990     0.0
#           Male          1.0             1.0        97906.380     0.0
# Spain     Female        1.0             1.0       103035.900     0.0
# ...

# %%
df.groupby(['Geography','Tenure']).median()
# Out:
#                   CreditScore   Age     Balance  NumOfProducts  HasCrCard  \
# Geography Tenure
# France    0.0           649.0  38.0   80793.580            1.0        1.0
#           1.0           651.5  37.0   72378.595            1.0        1.0
#           2.0           653.5  37.0   58409.045            2.0        1.0
#           3.0           654.0  37.0   73309.380            1.0        1.0
#           4.0           655.0  36.0   68604.465            2.0        1.0
#           5.0           654.5  37.0       0.000            1.0        1.0
#           6.0           652.0  37.0       0.000            1.0        1.0
#           7.0           650.0  37.0   51799.290            2.0        1.0
#           8.0           651.0  36.0   66738.540            1.0        1.0
#           9.0           660.0  37.0       0.000            1.0        1.0
#           10.0          651.5  38.0   55571.170            2.0        1.0
# ...

# %%
#df[pd.isnull(df['Geography'])].apply(lambda x : x.fillna('Germany') if x['Balance'] > 100000)

# %%
#df[pd.isnull(df['Geography'] & df.Balance > 100000].apply(lambda x : x[3].fillna('Germany'))

# %%
#df[df.Balance > 100000] = df[df.Balance > 100000]['Geography'].apply(lambda x : x.fillna('Germany'))

# %%
#df.loc[[df.Balance > 100000], 'Geography'].fillna('Germany', inplace=True)

# %%
df.loc[df.Balance > 100000, 'Geography'] = df.loc[df.Balance > 100000, 'Geography'].fillna('Germany')

# %%
df.loc[(df.Balance == 0) & (df.Tenure == 10), 'Geography'] = df.loc[(df.Balance == 0) & (df.Tenure == 10), 'Geography'].fillna('Spain')

# %%
df.Geography.fillna('France' , inplace=True)

# %%
df[pd.isnull(df['Geography'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['Gender'])]
# Out:
#                Surname  CreditScore Geography Gender   Age  Tenure    Balance  \
# CustomerId
# 15783349      Montague        481.0     Spain    NaN  39.0     1.0  111233.09
# 15636595         Loton        602.0     Spain    NaN  37.0     3.0  107592.89
# 15776404    Williamson        523.0    France    NaN  22.0     8.0  123374.46
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15783349              1.0        1.0             1.0        123995.15     0.0
# 15636595              2.0        0.0             1.0        153122.73     0.0
# 15776404              1.0        1.0             1.0        124906.59     0.0

# %%
df.loc[(df.Age == 22) , :].groupby(['Geography','Gender']).median()
# Out:
#                   CreditScore   Age  Tenure     Balance  NumOfProducts  \
# Geography Gender
# France    Female        662.0  22.0     6.0   95189.275            1.5
#           Male          632.0  22.0     5.0       0.000            2.0
# Germany   Female        631.0  22.0     6.0  111543.260            1.0
#           Male          675.5  22.0     6.0  103287.340            2.0
# Spain     Female        588.0  22.0     7.0   98800.000            1.0
#           Male          686.0  22.0     5.0       0.000            2.0
#
#                   HasCrCard  IsActiveMember  EstimatedSalary  Exited
# Geography Gender
# France    Female        1.0             1.0        92792.365     0.0
#           Male          1.0             0.0       106370.540     0.0
# Germany   Female        0.0             0.0        63747.510     0.0
#           Male          0.5             0.5        72243.770     0.0
# Spain     Female        1.0             1.0       101311.950     0.0
# ...

# %%
df.loc[df.Geography == 'Spain', 'Gender'] = df.loc[df.Geography == 'Spain', 'Gender'].fillna('Male')

# %%
df.loc[df.Geography == 'France', 'Gender'] = df.loc[df.Geography == 'France', 'Gender'].fillna('Female')

# %%
#df.Gender.fillna(method = 'ffill' , inplace=True)

# %%
df[pd.isnull(df['Gender'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['Age'])]
# Out:
#              Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# CustomerId
# 15708710        Ford        525.0     Spain  Female  NaN     0.0       0.00
# 15601274       Hsieh        667.0     Spain  Female  NaN     1.0  146502.07
# 15784844       K'ung        752.0     Spain    Male  NaN     5.0  116060.08
# 15631681     Jibunoh        807.0     Spain  Female  NaN     0.0       0.00
# 15718944    Artemiev        573.0    France  Female  NaN     6.0       0.00
# 15642579       Chang        731.0     Spain  Female  NaN     1.0  128932.40
# 15658577      Massie        629.0    France  Female  NaN    10.0   99546.25
# 15710365     Thomson        646.0    France    Male  NaN     0.0  104129.24
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15708710              1.0        0.0             1.0        131521.72     0.0
# 15601274              1.0        1.0             0.0         19162.89     0.0
# ...

# %%
df.loc[(df.Gender == 'Female') & (df.Geography == 'Spain'), :].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# Geography
# Spain            653.0  38.0     5.0      0.0            2.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# Spain                 1.0         103035.9     0.0

# %%
df.loc[(df.Gender == 'Male') & (df.Geography == 'Spain'), :].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# Geography
# Spain            650.0  37.0     5.0  69543.355            1.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# Spain                 1.0         95562.81     0.0

# %%
df.loc[(df.Gender == 'Female') & (df.Geography == 'France'), :].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# Geography
# France           652.0  37.0     5.0  47450.425            2.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                1.0        99520.855     0.0

# %%
df.loc[(df.Gender == 'Male') & (df.Geography == 'France'), :].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# Geography
# France           654.0  37.0     5.0  69278.675            1.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                1.0          98931.5     0.0

# %%
df.loc[(df.Gender == 'Female') & (df.Geography == 'Spain'), 'Age'] = df.loc[(df.Gender == 'Female') & (df.Geography == 'Spain'), 'Age'].fillna(38)

# %%
df.Age.fillna(37 , inplace=True)

# %%
df[pd.isnull(df['Age'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
#b = df.Age.mean()
#b
# Out:
# 38.920036028823056

# %%
#df.Age.fillna(int(b) , inplace=True)

# %%
df[pd.isnull(df['Tenure'])]
# Out:
#             Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15593976    Swanson        578.0   Germany  Female  31.0     NaN  102088.68
# 15800251      Elder        583.0   Germany  Female  26.0     NaN   72835.56
# 15680399       Tung        772.0    France    Male  23.0     NaN       0.00
# 15632789    Maclean        794.0    France    Male  30.0     NaN       0.00
# 15642785    Douglas        479.0    France    Male  34.0     NaN  117593.48
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15593976              4.0        0.0             0.0        187866.21     1.0
# 15800251              2.0        1.0             0.0         96792.15     0.0
# 15680399              2.0        1.0             0.0              NaN     0.0
# 15632789              2.0        1.0             1.0         24113.91     0.0
# 15642785              2.0        0.0             0.0        113308.29     0.0

# %%
df.loc[(df.Gender=='Female') & (df.CreditScore < 600), :].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# Geography
# France           544.0  37.0     5.0   33563.95            1.0        1.0
# Germany          547.0  39.0     5.0  122189.66            1.0        1.0
# Spain            547.0  38.0     5.0       0.00            2.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                0.0        100200.40     0.0
# Germany               0.0        106761.47     0.0
# Spain                 1.0        103608.06     0.0

# %%
df.loc[(df.Gender=='Male') & (df.CreditScore > 600), :].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure     Balance  NumOfProducts  HasCrCard  \
# Geography
# France           691.0  37.0     5.0   71887.355            1.0        1.0
# Germany          693.0  37.0     5.0  119545.480            1.0        1.0
# Spain            691.0  37.0     5.0   75801.740            1.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                1.0        101141.28     0.0
# Germany               1.0         98530.62     0.0
# Spain                 1.0         95908.69     0.0

# %%
df.Tenure.fillna(5 , inplace=True)

# %%
df[pd.isnull(df['Tenure'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['Balance'])]
# Out:
#            Surname  CreditScore Geography  Gender   Age  Tenure  Balance  \
# CustomerId
# 15663441    Golibe        700.0   Germany  Female  40.0     4.0      NaN
# 15802617    Hudson        697.0   Germany    Male  43.0     7.0      NaN
# 15749114    Bailey        634.0     Spain    Male  35.0     3.0      NaN
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15663441              1.0        1.0             0.0        189826.96     1.0
# 15802617              2.0        1.0             0.0         64139.10     0.0
# 15749114              2.0        1.0             1.0         19515.48     0.0

# %%
df.loc[(df.Gender=='Female') & (df.Tenure==4) & (df.Age==40),:].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# Geography
# France           583.5  40.0     4.0  67851.875            2.0        0.5
# Germany          694.5  40.0     4.0  78119.590            2.0        1.0
# Spain            641.0  40.0     4.0      0.000            2.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                0.0        57188.355     0.0
# Germany               0.0       117529.720     1.0
# Spain                 0.0       105433.530     0.0

# %%
df.loc[(df.Gender=='Male') & (df.Age==43),:].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure     Balance  NumOfProducts  HasCrCard  \
# Geography
# France           663.5  43.0     5.0   89987.195            2.0        1.0
# Germany          685.0  43.0     5.0  120403.245            2.0        1.0
# Spain            643.0  43.0     5.0   97392.180            1.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                0.0         86721.50     0.0
# Germany               1.0        107155.40     0.0
# Spain                 0.0        104769.96     0.0

# %%
df.loc[(df.Gender=='Male') & (df.Tenure==3) & (df.Age==35),:].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# Geography
# France           699.0  35.0     3.0  113640.81            1.0        1.0
# Germany          647.0  35.0     3.0  104356.38            1.0        1.0
# Spain            703.0  35.0     3.0       0.00            1.5        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                1.0        73112.355     0.0
# Germany               1.0       120511.030     0.0
# Spain                 1.0        87986.230     0.0

# %%
df.loc[(df.Gender == 'Female') & (df.Geography == 'Germany'), 'Balance'] = df.loc[(df.Gender == 'Female') & (df.Geography == 'Germany'), 'Balance'].fillna(80000)

# %%
df.loc[(df.Gender == 'Male') & (df.Geography == 'Germany'), 'Balance'] = df.loc[(df.Gender == 'Male') & (df.Geography == 'Germany'), 'Balance'].fillna(120000)

# %%
df.loc[(df.Gender == 'Male') & (df.Geography == 'Spain'), 'Balance'] = df.loc[(df.Gender == 'Male') & (df.Geography == 'Spain'), 'Balance'].fillna(0)

# %%
df[pd.isnull(df['Balance'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['NumOfProducts'])]
# Out:
#              Surname  CreditScore Geography  Gender   Age  Tenure    Balance  \
# CustomerId
# 15723654        Tsao        773.0    France    Male  25.0     2.0  135903.33
# 15583456    Gardiner        745.0   Germany    Male  45.0    10.0  117231.63
# 15769051        Shaw        503.0     Spain    Male  25.0     7.0       0.00
# 15765287       Grant        850.0    France  Female  38.0     2.0       0.00
# 15615670    Kazakova        762.0    France    Male  36.0     5.0  119547.46
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15723654              NaN        1.0             0.0         73656.38     0.0
# 15583456              NaN        1.0             1.0        122381.02     1.0
# 15769051              NaN        0.0             1.0        192841.13     0.0
# 15765287              NaN        1.0             0.0          9015.07     0.0
# 15615670              NaN        1.0             1.0         42693.65     0.0

# %%
df.loc[(df.Gender=='Male'),:].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure     Balance  NumOfProducts  HasCrCard  \
# Geography
# France           654.0  37.0     5.0   69278.675            1.0        1.0
# Germany          651.0  38.0     5.0  120135.550            1.0        1.0
# Spain            650.0  37.0     5.0   69478.570            1.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                1.0         98931.50     0.0
# Germany               1.0         97906.38     0.0
# Spain                 1.0         95562.81     0.0

# %%
df.loc[(df.Gender=='Female'),:].groupby('Geography').median()
# Out:
#            CreditScore   Age  Tenure     Balance  NumOfProducts  HasCrCard  \
# Geography
# France           652.0  37.0     5.0   47450.425            2.0        1.0
# Germany          651.0  39.0     5.0  118897.100            1.0        1.0
# Spain            653.0  38.0     5.0       0.000            2.0        1.0
#
#            IsActiveMember  EstimatedSalary  Exited
# Geography
# France                1.0        99520.855     0.0
# Germany               0.0       104617.990     0.0
# Spain                 1.0       103035.900     0.0

# %%
df.loc[(df.Gender == 'Female') & (df.Geography == 'France'), 'NumOfProducts'] = df.loc[(df.Gender == 'Female') & (df.Geography == 'France'), 'NumOfProducts'].fillna(2)

# %%
#df.NumOfProducts.value_counts()
# Out:
# 1.0    5081
# 2.0    4589
# 3.0     265
# 4.0      60
# Name: NumOfProducts, dtype: int64

# %%
df.NumOfProducts.fillna(1 , inplace=True)

# %%
df[pd.isnull(df['NumOfProducts'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['HasCrCard'])]
# Out:
#                   Surname  CreditScore Geography  Gender   Age  Tenure  \
# CustomerId
# 15600882            Scott        635.0     Spain  Female  35.0     7.0
# 15677371               Ko        629.0     Spain  Female  30.0     2.0
# 15807432            Cheng        645.0   Germany  Female  37.0     2.0
# 15675964    Chukwukadibia        672.0    France  Female  45.0     9.0
# 15807008         McGregor        614.0   Germany  Female  35.0     6.0
# 15585835             Lord        655.0     Spain  Female  34.0     4.0
# 15589949          Maclean        433.0     Spain    Male  34.0     9.0
#
#               Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# CustomerId
# 15600882         0.00            2.0        NaN             1.0
# 15677371     34013.63            1.0        NaN             0.0
# 15807432    136925.09            2.0        NaN             1.0
# 15675964         0.00            1.0        NaN             1.0
# ...

# %%
df.HasCrCard.fillna(1 , inplace=True)

# %%
df[pd.isnull(df['HasCrCard'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['IsActiveMember'])]
# Out:
#            Surname  CreditScore Geography Gender   Age  Tenure    Balance  \
# CustomerId
# 15697625     Bevan        791.0    France   Male  37.0     2.0  163789.49
# 15717893    Briggs        607.0   Germany   Male  36.0     8.0  143421.74
# 15637235    Knight        794.0     Spain   Male  33.0     8.0       0.00
# 15710671    Gordon        786.0    France   Male  34.0     3.0  137361.96
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15697625              2.0        1.0             NaN         75832.53     0.0
# 15717893              1.0        1.0             NaN         97879.02     0.0
# 15637235              2.0        0.0             NaN         91340.02     0.0
# 15710671              1.0        0.0             NaN        183682.09     0.0

# %%
df.IsActiveMember.fillna(1 , inplace=True)

# %%
df[pd.isnull(df['IsActiveMember'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[pd.isnull(df['EstimatedSalary'])]
# Out:
#               Surname  CreditScore Geography Gender   Age  Tenure  Balance  \
# CustomerId
# 15798906          Cox        628.0    France   Male  69.0     5.0      0.0
# 15569572    Sopuluchi        778.0    France   Male  42.0     6.0      0.0
# 15680399         Tung        772.0    France   Male  23.0     5.0      0.0
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15798906              2.0        1.0             1.0              NaN     0.0
# 15569572              2.0        1.0             1.0              NaN     0.0
# 15680399              2.0        1.0             0.0              NaN     0.0

# %%
df.EstimatedSalary.fillna(99000 , inplace=True)

# %%
df[pd.isnull(df['EstimatedSalary'])]
# Out:
# Empty DataFrame
# Columns: [Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
# Out:
# (735, 12)

# %%
df.loc[(df.IsActiveMember==1)&(df.Exited==1),:].shape
# Out:
# (735, 12)

# %%
df[pd.isnull(df['Exited'])]
# Out:
#              Surname  CreditScore Geography Gender   Age  Tenure    Balance  \
# CustomerId
# 15639415    Thompson        850.0    France   Male  35.0     3.0  162442.35
# 15581280    Atkinson        714.0   Germany   Male  29.0     6.0   92887.13
# 15693926         Pan        670.0     Spain   Male  37.0     0.0  178742.71
# 15737025     Roberts        635.0    France   Male  33.0     1.0       0.00
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# CustomerId
# 15639415              1.0        1.0             0.0        183566.78     NaN
# 15581280              1.0        1.0             1.0         69578.49     NaN
# 15693926              1.0        1.0             1.0        194493.57     NaN
# 15737025              3.0        0.0             0.0        178067.33     NaN

# %%
df.Exited.fillna(0 , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 15634602 to 15628319
# Data columns (total 12 columns):
# Surname            9996 non-null object
# CreditScore        9997 non-null float64
# Geography          9994 non-null object
# Gender             9997 non-null object
# Age                10000 non-null float64
# Tenure             10000 non-null float64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null float64
# HasCrCard          10000 non-null float64
# IsActiveMember     10000 non-null float64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null float64
# dtypes: float64(9), object(3)
# memory usage: 1015.6+ KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.532900     38.919300      5.012300   76459.494987       1.530100
# std       96.636801     10.486705      2.891433   62401.399885       0.581488
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97145.940000       1.000000
# 75%      717.250000     44.000000      7.000000  127639.372500       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#           HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.000000    10000.000000     10000.000000  10000.000000
# mean       0.705300        0.514700    100059.587258      0.203200
# ...

# %%
df.Geography.value_counts()
# Out:
# France     5012
# Germany    2512
# Spain      2476
# Name: Geography, dtype: int64

# %%
df.NumOfProducts.value_counts()
# Out:
# 1.0    5084
# 2.0    4591
# 3.0     265
# 4.0      60
# Name: NumOfProducts, dtype: int64

# %%
df.HasCrCard.value_counts()
# Out:
# 1.0    7053
# 0.0    2947
# Name: HasCrCard, dtype: int64

# %%
df.Exited.value_counts()
# Out:
#  0.0    7960
#  1.0    2036
# -1.0       4
# Name: Exited, dtype: int64

# %%
df.IsActiveMember.value_counts()
# Out:
#  1.0    5151
#  0.0    4845
# -1.0       4
# Name: IsActiveMember, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Male      5456
# Female    4544
# Name: Gender, dtype: int64
